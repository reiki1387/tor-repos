# %%
import pandas as pd
df_csv = pd.read_csv(r'C:\Users\FRED\Desktop\FreeCodeCamp- Data Analyst BootCamp for Beginners\Pandas Reading Files\Company_data(edited).csv', index_col = "Name")
df_csv
# Out:
#                                         Industry Revenue (USD millions)  \
# Name
# Walmart                                   Retail                648,125
# Amazon                Retail and cloud computing                574,785
# Apple                       Electronics industry                383,482
# UnitedHealth Group                    Healthcare                371,622
# Berkshire Hathaway                  Conglomerate                364,482
# ...                                          ...                    ...
# TIAA                                  Financials                 45,735
# CHS                      Agriculture cooperative                 45,590
# Bristol-Myers Squibb     Pharmaceutical industry                 45,006
# Dow Chemical Company           Chemical industry                 44,622
# Best Buy                                  Retail                 43,452
#
#                      Revenue growth  Employees                    Headquarters
# Name
# ...

# %%
df_csv.reset_index(inplace =True)

# %%
df_csv
# Out:
#                     Name                    Industry Revenue (USD millions)  \
# 0                Walmart                      Retail                648,125
# 1                 Amazon  Retail and cloud computing                574,785
# 2                  Apple        Electronics industry                383,482
# 3     UnitedHealth Group                  Healthcare                371,622
# 4     Berkshire Hathaway                Conglomerate                364,482
# ..                   ...                         ...                    ...
# 95                  TIAA                  Financials                 45,735
# 96                   CHS     Agriculture cooperative                 45,590
# 97  Bristol-Myers Squibb     Pharmaceutical industry                 45,006
# 98  Dow Chemical Company           Chemical industry                 44,622
# 99              Best Buy                      Retail                 43,452
#
# ...

# %%
df_csv.set_index('Name', inplace = True)
df_csv
# Out:
#                                         Industry Revenue (USD millions)  \
# Name
# Walmart                                   Retail                648,125
# Amazon                Retail and cloud computing                574,785
# Apple                       Electronics industry                383,482
# UnitedHealth Group                    Healthcare                371,622
# Berkshire Hathaway                  Conglomerate                364,482
# ...                                          ...                    ...
# TIAA                                  Financials                 45,735
# CHS                      Agriculture cooperative                 45,590
# Bristol-Myers Squibb     Pharmaceutical industry                 45,006
# Dow Chemical Company           Chemical industry                 44,622
# Best Buy                                  Retail                 43,452
#
#                      Revenue growth  Employees                    Headquarters
# Name
# ...

# %%
df_csv.reset_index(inplace = True)
df_csv
# Out:
#     level_0  index                  Name                    Industry  \
# 0         0      0               Walmart                      Retail
# 1         1      1                Amazon  Retail and cloud computing
# 2         2      2                 Apple        Electronics industry
# 3         3      3    UnitedHealth Group                  Healthcare
# 4         4      4    Berkshire Hathaway                Conglomerate
# ..      ...    ...                   ...                         ...
# 95       95     95                  TIAA                  Financials
# 96       96     96                   CHS     Agriculture cooperative
# 97       97     97  Bristol-Myers Squibb     Pharmaceutical industry
# 98       98     98  Dow Chemical Company           Chemical industry
# 99       99     99              Best Buy                      Retail
#
#    Revenue (USD millions) Revenue growth  Employees  \
# 0                 648,125          6.00%  2,100,000
# ...

# %%
df_csv = df_csv.drop(columns=[col for col in df_csv.columns if col.startswith(('index', 'level_0'))])

# %%
df_csv
# Out:
#                     Name                    Industry Revenue (USD millions)  \
# 0                Walmart                      Retail                648,125
# 1                 Amazon  Retail and cloud computing                574,785
# 2                  Apple        Electronics industry                383,482
# 3     UnitedHealth Group                  Healthcare                371,622
# 4     Berkshire Hathaway                Conglomerate                364,482
# ..                   ...                         ...                    ...
# 95                  TIAA                  Financials                 45,735
# 96                   CHS     Agriculture cooperative                 45,590
# 97  Bristol-Myers Squibb     Pharmaceutical industry                 45,006
# 98  Dow Chemical Company           Chemical industry                 44,622
# 99              Best Buy                      Retail                 43,452
#
# ...

# %%
#Multi-indexing
df_csv.set_index(['Industry', 'Name'], inplace = True)
df_csv
# Out:
#                                                 Revenue (USD millions)  \
# Industry                   Name
# Retail                     Walmart                             648,125
# Retail and cloud computing Amazon                              574,785
# Electronics industry       Apple                               383,482
# Healthcare                 UnitedHealth Group                  371,622
# Conglomerate               Berkshire Hathaway                  364,482
# ...                                                                ...
# Financials                 TIAA                                 45,735
# Agriculture cooperative    CHS                                  45,590
# Pharmaceutical industry    Bristol-Myers Squibb                 45,006
# Chemical industry          Dow Chemical Company                 44,622
# Retail                     Best Buy                             43,452
#
#                                                 Revenue growth  Employees  \
# ...

# %%
#change table option to display all rows
pd.set_option('display.max.rows', 100)

#sort by first index. If have duplicates then sort by second index
df_csv.sort_index(inplace= True )
df_csv
# Out:
#                                                                         Revenue (USD millions)  \
# Industry                            Name
# Aerospace and defense               Boeing                                              77,794
#                                     Lockheed Martin                                     67,571
# Agriculture cooperative             CHS                                                 45,590
# Agriculture manufacturing           John Deere                                          61,251
# Airline                             American Airlines                                   52,788
#                                     Delta Air Lines                                     58,048
#                                     United Airlines                                     53,717
# Apparel                             Nike                                                51,217
# ...

# %%
df_csv.sort_index(inplace = True, ascending = [False, False])
df_csv
# Out:
#                                                                         Revenue (USD millions)  \
# Industry                            Name
# Transportation                      United Parcel Service                               90,958
#                                     FedEx                                               90,155
# Telecommunications                  Verizon Communications                             133,974
#                                     Comcast                                            121,572
#                                     Charter Communications                              54,607
# Telecom hardware manufacturing      Cisco                                               56,998
# Technology and cloud computing      Microsoft                                          211,915
#                                     IBM                                                 61,860
# ...

# %%
df_csv.iloc[3, 3]
# Out:
# 'Philadelphia, Pennsylvania'

# %%
df_csv.loc['Telecommunications', 'Comcast']
# Out:
# Revenue (USD millions)                       121,572
# Revenue growth                                 0.10%
# Employees                                    186,000
# Headquarters              Philadelphia, Pennsylvania
# Name: (Telecommunications, Comcast), dtype: object
