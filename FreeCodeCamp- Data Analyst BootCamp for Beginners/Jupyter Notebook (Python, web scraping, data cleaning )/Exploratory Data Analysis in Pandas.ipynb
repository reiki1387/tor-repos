# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_world = pd.read_csv(r"C:\Users\FRED\Desktop\FreeCodeCamp- Data Analyst BootCamp for Beginners\PandasYouTubeSeries\world_population.csv")
df_world
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
#Changing integers decimal format
# pd.set_option('display.float.format', lambda x: '%.2f' % x) #old style
# pd.set_option('display.float_format', '{:.2f}'.format)  # option 1
pd.set_option('display.float_format', lambda x: f'{x:.2f}') # option 2 (recommended)

# %%
# checking info of the table
df_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df_world.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
# df_world.boxplot(figsize = (20,15))

# %%
df_world.isnull()
# Out:
#       Rank   CCA3  Country  Capital  Continent  2022 Population  \
# 0    False  False    False    False      False            False
# 1    False  False    False    False      False            False
# 2    False  False    False    False      False            False
# 3    False  False    False    False      False            False
# 4    False  False    False    False      False            False
# ..     ...    ...      ...      ...        ...              ...
# 229  False  False    False    False      False            False
# 230  False  False    False    False      False            False
# 231  False  False    False    False      False            False
# 232  False  False    False    False      False            False
# 233  False  False    False    False      False            False
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 0              False            False            False            False
# ...

# %%
df_world.isna()
# Out:
#       Rank   CCA3  Country  Capital  Continent  2022 Population  \
# 0    False  False    False    False      False            False
# 1    False  False    False    False      False            False
# 2    False  False    False    False      False            False
# 3    False  False    False    False      False            False
# 4    False  False    False    False      False            False
# ..     ...    ...      ...      ...        ...              ...
# 229  False  False    False    False      False            False
# 230  False  False    False    False      False            False
# 231  False  False    False    False      False            False
# 232  False  False    False    False      False            False
# 233  False  False    False    False      False            False
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 0              False            False            False            False
# ...

# %%
#Display all rows that have null values
df_world[df_world.isna().any(axis=1)]
# Out:
#      Rank CCA3              Country        Capital      Continent  \
# 13     91  AZE           Azerbaijan           Baku           Asia
# 42     28  COL             Colombia         Bogota  South America
# 59    152  GNQ    Equatorial Guinea         Malabo         Africa
# 62    159  SWZ             Eswatini        Mbabane         Africa
# 72    142  GMB               Gambia         Banjul         Africa
# 73    131  GEO              Georgia        Tbilisi           Asia
# 90     94  HUN              Hungary       Budapest         Europe
# 91    179  ISL              Iceland      Reykjavík         Europe
# 92      2  IND                India      New Delhi           Asia
# 100    52  CIV          Ivory Coast   Yamoussoukro         Africa
# 101   139  JAM              Jamaica       Kingston  North America
# 122    45  MYS             Malaysia   Kuala Lumpur           Asia
# 123   174  MDV             Maldives           Malé           Asia
# ...

# %%
#check null values in specific columsn
df_world[df_world[['2022 Population', '2020 Population']].isna().any(axis=1)]
# Out:
#      Rank CCA3      Country    Capital Continent  2022 Population  \
# 13     91  AZE   Azerbaijan       Baku      Asia      10358074.00
# 62    159  SWZ     Eswatini    Mbabane    Africa              NaN
# 154   120  NOR       Norway       Oslo    Europe              NaN
# 157   222  PLW        Palau  Ngerulmud   Oceania              NaN
# 207   155  TLS  Timor-Leste       Dili      Asia              NaN
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 13               NaN       9863480.00       9237202.00       8190337.00
# 62        1180655.00       1133936.00       1099920.00       1030496.00
# 154       5379839.00              NaN       4889741.00       4491202.00
# 157         17972.00         17794.00         18540.00         19726.00
# 207       1299995.00       1205813.00       1088486.00              NaN
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
#Check for unique values
df_world.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
 #Find all duplicate rows (complete duplicates across all columns)
duplicate_rows = df_world[df_world.duplicated(keep=False)]

# Sort by values to group duplicates together
duplicate_rows = duplicate_rows.sort_values(by=list(df_world.columns))
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Rank, CCA3, Country, Capital, Continent, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []

# %%
#Sorting by continent and displaying the first 5 rows
df_world.sort_values(by= "Continent", ascending = False).head()
# Out:
#      Rank CCA3           Country   Capital      Continent  2022 Population  \
# 27      7  BRA            Brazil  Brasilia  South America     215313498.00
# 227    51  VEN         Venezuela   Caracas  South America      28301696.00
# 162    44  PER              Peru      Lima  South America      34049588.00
# 64    231  FLK  Falkland Islands   Stanley  South America          3780.00
# 42     28  COL          Colombia    Bogota  South America      51874024.00
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 27      213196304.00     205188205.00     196353492.00     175873720.00
# 227      28490453.00      30529716.00      28715022.00              NaN
# 162      33304756.00      30711863.00      29229572.00      26654439.00
# 64           3747.00          3408.00          3187.00          3080.00
# 42       50930662.00      47119728.00              NaN      39215135.00
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
# Checking for correaltion of numeric values
df_world.corr(numeric_only = True)
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
plt.figure(figsize = (12,10))
sns.heatmap(df_world.corr(numeric_only = True), annot =True)
# Out:
# <Axes: >

# %%
df_world.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df_world_1 = df_world.groupby('Continent')[['2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population', '1990 Population',
       '1980 Population', '1970 Population']].mean(numeric_only = True).sort_values(by="2022 Population",ascending = False)

df_world_1
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia               96327387.31      94955134.37      89165003.64
# South America      31201186.29      30823574.50      29509599.71
# Africa             25455879.68      23871435.26      21419703.57
# Europe             15055371.82      14915843.92      15027454.12
# North America      15007403.40      14855914.82      14259596.25
# Oceania             2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               89087770.00      80580835.11      48639995.33
# South America      26789395.54      25015888.69      21224743.93
# Africa             18898197.31      14598365.95      11376964.52
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
#
# ...

# %%
#Alternative way is indexing to show only desired columns
# df_world.groupby('Continent')[df_world.columns[5:13]].mean(numeric_only = True).sort_values(by="2022 Population",ascending = False)

# %%
df_world_1.plot(figsize = (13,5))
# Out:
# <Axes: xlabel='Continent'>

# %%
df_world_1_transposed = df_world_1.transpose()
df_world_1_transposed
# Out:
# Continent              Asia  South America      Africa      Europe  \
# 2022 Population 96327387.31    31201186.29 25455879.68 15055371.82
# 2020 Population 94955134.37    30823574.50 23871435.26 14915843.92
# 2015 Population 89165003.64    29509599.71 21419703.57 15027454.12
# 2010 Population 89087770.00    26789395.54 18898197.31 14712278.68
# 2000 Population 80580835.11    25015888.69 14598365.95 14817685.71
# 1990 Population 48639995.33    21224743.93 11376964.52 14785203.94
# 1980 Population 40278333.33    17270643.29  8586031.98 14200004.52
# 1970 Population 43839877.83    13781939.71  6567175.27 13118479.82
#
# Continent        North America    Oceania
# 2022 Population    15007403.40 2046386.32
# 2020 Population    14855914.82 1910148.96
# 2015 Population    14259596.25 1756664.48
# 2010 Population    13568016.28 1613163.65
# 2000 Population    12151739.60 1357512.09
# 1990 Population    10531660.62 1162774.87
# 1980 Population     9207334.03  996532.17
# ...

# %%
df_world_1_transposed.plot(figsize = (13,5))
# Out:
# <Axes: >

# %%
df_world[df_world["Continent"] == "Oceania"]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
df_world.boxplot(figsize= (19,10))
# Out:
# <Axes: >

# %%
   # For a specific column (replace 'column_name' with your actual column name)
   Q1 = df_world['2022 Population'].quantile(0.25)
   Q3 = df_world['2022 Population'].quantile(0.75)
   IQR = Q3 - Q1
   print(f'Q1:{Q1} , Q3: {Q3} , IQR: {IQR}')
   
   # Define outliers as points beyond 1.5 * IQR from Q1 or Q3
   outliers = df_world[(df_world['2022 Population'] < (Q1 - 1.5 * IQR)) | 
                       (df_world['2022 Population'] > (Q3 + 1.5 * IQR))]
   print(f'Outliers : {outliers}')
# Out:
# Q1:419738.5 , Q3: 22653719.0 , IQR: 22233980.5
# Outliers :      Rank CCA3         Country           Capital      Continent  \
# 16      8  BGD      Bangladesh             Dhaka           Asia
# 27      7  BRA          Brazil          Brasilia  South America
# 41      1  CHN           China           Beijing           Asia
# 55     15  COD        DR Congo          Kinshasa         Africa
# 57     14  EGY           Egypt             Cairo         Africa
# 63     12  ETH        Ethiopia       Addis Ababa         Africa
# 68     23  FRA          France             Paris         Europe
# 74     19  DEU         Germany            Berlin         Europe
# 92      2  IND           India         New Delhi           Asia
# 93      4  IDN       Indonesia           Jakarta           Asia
# 94     17  IRN            Iran            Tehran           Asia
# 99     25  ITA           Italy              Rome         Europe
# 102    11  JPN           Japan             Tokyo           Asia
# ...

# %%
#fuunction for finding outliers
# def find_outliers(df):
#        outlier_indices = {}
#        for col in df.select_dtypes(include=['number']).columns:
#            Q1 = df[col].quantile(0.25)
#            Q3 = df[col].quantile(0.75)
#            IQR = Q3 - Q1
#            outlier_step = 1.5 * IQR
#            outlier_list = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step)].index
#            outlier_indices[col] = list(outlier_list)
#        return outlier_indices
   
#    outliers = find_outliers(df_world)
   
#    # To see countries with outliers in a specific column
#    print(df_world.loc[outliers['2022 Population']])

# %%
df_world.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
#displays specific data type only
df_world.select_dtypes(include = 'object')
# Out:
#     CCA3            Country           Capital Continent
# 0    AFG        Afghanistan             Kabul      Asia
# 1    ALB            Albania            Tirana    Europe
# 2    DZA            Algeria           Algiers    Africa
# 3    ASM     American Samoa         Pago Pago   Oceania
# 4    AND            Andorra  Andorra la Vella    Europe
# ..   ...                ...               ...       ...
# 229  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  ESH     Western Sahara          El Aaiún    Africa
# 231  YEM              Yemen             Sanaa      Asia
# 232  ZMB             Zambia            Lusaka    Africa
# 233  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 4 columns]
