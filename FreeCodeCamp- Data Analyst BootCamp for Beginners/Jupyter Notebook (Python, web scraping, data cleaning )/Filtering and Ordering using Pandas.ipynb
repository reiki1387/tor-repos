# %%
import pandas as pd
df_excel = pd.read_excel(r'C:\Users\FRED\Desktop\FreeCodeCamp- Data Analyst BootCamp for Beginners\Pandas Reading Files\vgsales.xlsx')
df_excel
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df_excel[df_excel['Rank'] <= 5]
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
specific_genre = ['Sports', 'Racing']
df_excel[df_excel['Genre'].isin(specific_genre)]
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 11        12                                     Mario Kart DS       DS
# 13        14                                           Wii Fit      Wii
# ...      ...                                               ...      ...
# 16578  16581                     Outdoors Unleashed: Africa 3D      3DS
# 16579  16582                                 PGA European Tour      N64
# 16581  16584                                         Fit & Fun      Wii
# 16587  16590                          Mezase!! Tsuri Master DS       DS
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
#
#          Year   Genre    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df_excel[df_excel['Name'].str.contains('Wii')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_excel[df_excel['Name'].str.contains('Wii')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4092, in DataFrame.__getitem__(self, key)
#    4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
# -> 4092 if com.is_bool_indexer(key):
#    4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
#     134         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %%
#Check if there are any null values in the column "Name"
df_excel[df_excel['Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
#Check the data types of each rows in the column "Name"
df_excel['Name'].apply(type).value_counts()
# Out:
# Name
# <class 'str'>    16597
# <class 'int'>        1
# Name: count, dtype: int64

# %%
#Display the row of the integer data type in the column "Name"
df_excel[df_excel['Name'].apply(lambda x: isinstance(x, int))]
# Out:
#       Rank  Name Platform    Year    Genre Publisher  NA_Sales  EU_Sales  \
# 2059  2061  1942      NES  1985.0  Shooter    Capcom      0.65      0.14
#
#       JP_Sales  Other_Sales  Global_Sales
# 2059      0.21          0.0           1.0

# %%
#Display only the data in the column "Name" that is a integer
df_excel['Name'][df_excel['Name'].apply(lambda x: isinstance(x, int))]
# Out:
# 2059    1942
# Name: Name, dtype: object

# %%
#Convert all the data in the column "Name" to str
df_excel['Name'] = df_excel['Name'].astype(str)

# %%
df_excel[df_excel['Name'].str.contains('Wii')]
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 13        14                                            Wii Fit      Wii
# 14        15                                       Wii Fit Plus      Wii
# 78        79                                          Wii Party      Wii
# 97        98                Super Smash Bros. for Wii U and 3DS      3DS
# 203      204                Super Smash Bros. for Wii U and 3DS     WiiU
# 320      321                      Big Brain Academy: Wii Degree      Wii
# 412      413                                          Wii Music      Wii
# ...

# %%
#cleaning the column name
df_excel.columns = df_excel.columns.str.strip()

# %%
#changing index using the column name
df_excel = df_excel.set_index('Name')
df_excel
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %%
df_excel = df_excel.reset_index()
df_excel
# Out:
#                                                    Name   Rank Platform  \
# 0                                            Wii Sports      1      Wii
# 1                                     Super Mario Bros.      2      NES
# 2                                        Mario Kart Wii      3      Wii
# 3                                     Wii Sports Resort      4      Wii
# 4                              Pokemon Red/Pokemon Blue      5       GB
# ...                                                 ...    ...      ...
# 16593                Woody Woodpecker in Crazy Castle 5  16596      GBA
# 16594                     Men in Black II: Alien Escape  16597       GC
# 16595  SCORE International Baja 1000: The Official Game  16598      PS2
# 16596                                        Know How 2  16599       DS
# 16597                                  Spirits & Spells  16600      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
 df_excel.filter(items = ['Name', 'Publisher', 'Global_Sales'])
# Out:
#                                                    Name   Publisher  \
# 0                                            Wii Sports    Nintendo
# 1                                     Super Mario Bros.    Nintendo
# 2                                        Mario Kart Wii    Nintendo
# 3                                     Wii Sports Resort    Nintendo
# 4                              Pokemon Red/Pokemon Blue    Nintendo
# ...                                                 ...         ...
# 16593                Woody Woodpecker in Crazy Castle 5       Kemco
# 16594                     Men in Black II: Alien Escape  Infogrames
# 16595  SCORE International Baja 1000: The Official Game  Activision
# 16596                                        Know How 2    7G//AMES
# 16597                                  Spirits & Spells     Wanadoo
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# ...

# %%
 df_excel.filter(items = ['Name', 'Publisher', 'Global_Sales'], axis = 1)
# Out:
#                                                    Name   Publisher  \
# 0                                            Wii Sports    Nintendo
# 1                                     Super Mario Bros.    Nintendo
# 2                                        Mario Kart Wii    Nintendo
# 3                                     Wii Sports Resort    Nintendo
# 4                              Pokemon Red/Pokemon Blue    Nintendo
# ...                                                 ...         ...
# 16593                Woody Woodpecker in Crazy Castle 5       Kemco
# 16594                     Men in Black II: Alien Escape  Infogrames
# 16595  SCORE International Baja 1000: The Official Game  Activision
# 16596                                        Know How 2    7G//AMES
# 16597                                  Spirits & Spells     Wanadoo
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# ...

# %%
 df_excel.filter(items = [90,200], axis = 0)
# Out:
#                                        Name  Rank Platform    Year     Genre  \
# 90   Grand Theft Auto: Liberty City Stories    91      PSP  2005.0    Action
# 200                       Super Mario Bros.   201       GB  1999.0  Platform
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 90   Take-Two Interactive       2.9      2.83      0.24         1.75
# 200              Nintendo       3.4      1.30      0.15         0.22
#
#      Global_Sales
# 90           7.72
# 200          5.07

# %%
df_csv = pd.read_csv(r'C:\Users\FRED\Desktop\FreeCodeCamp- Data Analyst BootCamp for Beginners\Pandas Reading Files\Company_data(edited).csv')
df_csv = df_csv.set_index ('Name')
df_csv
# Out:
#                                         Industry Revenue (USD millions)  \
# Name
# Walmart                                   Retail                648,125
# Amazon                Retail and cloud computing                574,785
# Apple                       Electronics industry                383,482
# UnitedHealth Group                    Healthcare                371,622
# Berkshire Hathaway                  Conglomerate                364,482
# ...                                          ...                    ...
# TIAA                                  Financials                 45,735
# CHS                      Agriculture cooperative                 45,590
# Bristol-Myers Squibb     Pharmaceutical industry                 45,006
# Dow Chemical Company           Chemical industry                 44,622
# Best Buy                                  Retail                 43,452
#
#                      Revenue growth  Employees                    Headquarters
# Name
# ...

# %%
df_csv.filter(items = ['Walmart'], axis = 0 )
# Out:
#         Industry Revenue (USD millions) Revenue growth  Employees  \
# Walmart   Retail                648,125          6.00%  2,100,000
#
#                   Headquarters
# Walmart  Bentonville, Arkansas

# %%
df_csv.filter(like = 'Wal', axis = 0 )
# Out:
#                                          Industry Revenue (USD millions)  \
# Name
# Walmart                                    Retail                648,125
# Walgreens Boots Alliance  Pharmaceutical industry                139,081
# The Walt Disney Company                     Media                 88,898
#
#                          Revenue growth  Employees           Headquarters
# Name
# Walmart                           6.00%  2,100,000  Bentonville, Arkansas
# Walgreens Boots Alliance          4.80%    268,500    Deerfield, Illinois
# The Walt Disney Company           7.50%    199,125    Burbank, California

# %%
df_csv.iloc[2]
# Out:
# Industry                   Electronics industry
# Revenue (USD millions)                  383,482
# Revenue growth                           -2.80%
# Employees                               161,000
# Headquarters              Cupertino, California
# Name: Apple, dtype: object

# %%
df_csv.loc['Apple']
# Out:
# Industry                   Electronics industry
# Revenue (USD millions)                  383,482
# Revenue growth                           -2.80%
# Employees                               161,000
# Headquarters              Cupertino, California
# Name: Apple, dtype: object

# %%
df_excel.sort_values(by = 'Year')
# Out:
#                               Name   Rank Platform    Year         Genre  \
# 6896                      Checkers   6898     2600  1980.0          Misc
# 2669                        Boxing   2671     2600  1980.0      Fighting
# 5366                       Freeway   5368     2600  1980.0        Action
# 1969                      Defender   1971     2600  1980.0          Misc
# 1766                       Kaboom!   1768     2600  1980.0          Misc
# ...                            ...    ...      ...     ...           ...
# 16307                Freaky Flyers  16310       GC     NaN        Racing
# 16327                    Inversion  16330       PC     NaN       Shooter
# 16366  Hakuouki: Shinsengumi Kitan  16369      PS3     NaN     Adventure
# 16427                 Virtua Quest  16430       GC     NaN  Role-Playing
# 16493                   The Smurfs  16496      3DS     NaN        Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df_excel[df_excel['Year'] > 2016].sort_values(by = 'Global_Sales')
# Out:
#                                                    Name   Rank Platform  \
# 16241  Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV
# 16438                  Brothers Conflict: Precious Baby  16441      PSV
# 14390  Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4
# 5957                             Imagine: Makeup Artist   5959       DS
#
#          Year         Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16241  2017.0  Role-Playing          Sega      0.00       0.0      0.01
# 16438  2017.0        Action  Idea Factory      0.00       0.0      0.01
# 14390  2017.0  Role-Playing          Sega      0.00       0.0      0.03
# 5957   2020.0    Simulation       Ubisoft      0.27       0.0      0.00
#
#        Other_Sales  Global_Sales
# 16241         0.00          0.01
# 16438         0.00          0.01
# 14390         0.00          0.03
# 5957          0.02          0.29

# %%
df_excel[df_excel['Year'] > 2016].sort_values(by = ['Global_Sales' , 'Genre'] , ascending= True)
# Out:
#                                                    Name   Rank Platform  \
# 16438                  Brothers Conflict: Precious Baby  16441      PSV
# 16241  Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV
# 14390  Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4
# 5957                             Imagine: Makeup Artist   5959       DS
#
#          Year         Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16438  2017.0        Action  Idea Factory      0.00       0.0      0.01
# 16241  2017.0  Role-Playing          Sega      0.00       0.0      0.01
# 14390  2017.0  Role-Playing          Sega      0.00       0.0      0.03
# 5957   2020.0    Simulation       Ubisoft      0.27       0.0      0.00
#
#        Other_Sales  Global_Sales
# 16438         0.00          0.01
# 16241         0.00          0.01
# 14390         0.00          0.03
# 5957          0.02          0.29
